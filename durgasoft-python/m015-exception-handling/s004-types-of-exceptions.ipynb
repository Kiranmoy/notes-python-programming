# %% [markdown]
# # Types of Exceptions

# %% [markdown]
# In Python, there are 2 types of exceptions that are possible.
# * **Pre-defined Exceptions**
# * **User-defined Exceptions**

# %% [markdown]
# # Pre-defined Exceptions

# %% [markdown]
# * Also known as inbuilt **exceptions**.
# * The exceptions which are raised automatically by Python virtual machine whenever a particular event occurs are called **pre-defined exceptions**.

# %%
# Whenever we are trying to perform Division by zero, automatically Python willraise ZeroDivisionError.
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Whenever we are trying to perform Division by zero, automatically Python willraise ZeroDivisionError.
# ----> 2 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
# Whenever we are trying to convert input value to int type, 
# and if input value isnot int value then Python will raise ValueError automatically.
x=int("ten")    # ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Whenever we are trying to convert input value to int type,
#       2 # and if input value isnot int value then Python will raise ValueError automatically.
# ----> 3 x=int("ten")    # ValueError
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # User-defined Exceptions

# %% [markdown]
# Also known as **customized exceptions** or **programmatic exceptions**.
#
# Sometimes we have to define and raise exceptions explicitly to indicate that something goes wrong, such types of exceptions are called **User Defined Exceptions** or **Customized Exceptions**.
#
# The programmer is responsible to define these exceptions and Python not having any idea about these.
#
# Hence we have to raise explicitly based on our requirement by using the "`raise`" keyword.
#
# **Example:**
# * `InSufficientFundsException`
# * `InvalidInputException`
# * `TooYoungException`
# * `TooOldException`

# %% [markdown]
# # How to define and raise customized exceptions?

# %% [markdown]
# Every exception in Python is a class that extends the **Exception** class either directly or indirectly.
#
# ![image.png](attachment:3a0b8206-b9e4-47f1-90be-23c225b650a2.png)

# %%
class TooYoungException(Exception):
  def __init__(self,arg):
    self.msg=arg

# %% [markdown]
# **`TooYoungException`** is our class name which is the child class of **Exception**.
#
# We can raise an exception by using the **`raise`** keyword as follows → **`raise TooYoungException("message")`**

# %%
class TooYoungException(Exception):
  def __init__(self,arg):
    self.msg=arg

class TooOldException(Exception):
  def __init__(self,arg):
    self.msg=arg

age=int(input("Enter Age:"))

if age > 60:
  raise TooYoungException("Plz wait some more time you will get best match soon!!!")
elif age < 18:
  raise TooOldException("Your age already crossed marriage age...no chance of getting marriage")
else:
  print("You will get match details soon by email!!!")
# Out:
# Enter Age: 90
# ---------------------------------------------------------------------------
# TooYoungException                         Traceback (most recent call last)
# Cell In[4], line 12
#       9 age=int(input("Enter Age:"))
#      11 if age > 60:
# ---> 12   raise TooYoungException("Plz wait some more time you will get best match soon!!!")
#      13 elif age < 18:
#      14   raise TooOldException("Your age already crossed marriage age...no chance of getting marriage")
#
# TooYoungException: Plz wait some more time you will get best match soon!!!

# %% [markdown]
# ![image.png](attachment:bc21063b-53bc-49ee-b0b3-a05f1d2f835c.png)
