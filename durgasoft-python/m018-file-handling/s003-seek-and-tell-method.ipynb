# %% [markdown]
# # tell( ) method

# %% [markdown]
# * We can use the **tell( )** method to return the current position of the cursor (file pointer) from the beginning of the file.
# * ***can you please tell current cursor position?**
# * The position(index) of the first character in files is zero just like the string index
#
# ```
# f=open("abc.txt","r")
# print(f.tell())
# print(f.read(2))
# print(f.tell())
# print(f.read(3))
# print(f.tell())
# ```
# ![image.png](attachment:5e2d88ab-f362-4735-b0e0-eb33ffe0d590.png)
#
# ![image.png](attachment:6f101ac0-3fc4-4aa1-aa3c-8eca183635fb.png)

# %% [markdown]
# # seek( ) method

# %% [markdown]
# We can use **seek( )** method to move the cursor (file pointer) to the specified location.
#
# **Can you please seek the cursor to a particular location?**
#
# **PYTHON 2. X**
#
# * `f.seek(offset, from-where)` → offset represents the number of positions
# * The allowed values for 2nd Attribute (from where) are:
# * `0` → From the beginning of the File (**Default Value**) → `f.seek(10, 0)`
# * `1` → From Current Position → `f.seek(10, 1)`
# * `2` → From the end of the File → `f.seek(10, 2)`
#
# > ***Note:** Python 2 supports all 3 values but Python 3 supports only zero.*
#
# **PYTHON 3. X**
# * Only zero is allowed as the starting position for **`seek( )`** method.
# * Hence we can seek only from the beginning of the file only.
#
# **Example:** `f.seek(3)`
#
# ```
# data="All Students are STUPIDS"
# f=open("abc.txt","w")
# f.write(data)
# with open("abc.txt","r+") as f:
#   text=f.read()
#   print(text)
#   print("The Current Cursor Position: ",f.tell())
#   f.seek(17)
#   print("The Current Cursor Position: ",f.tell())
#   f.write("GEMS!!!")
#   f.seek(0)
#   text=f.read()
#   print("Data After Modification:")
#   print(text)
# ```
#
# ![image.png](attachment:2ada8f3b-2277-4e5b-91bc-ced4033fb1ba.png)

# %% [markdown]
# # How to check if a particular File exists OR not?

# %% [markdown]
# * We can use the os library to get information about files on our computer.
# * The `os` module has a path sub-module, which contains the `isFile( )` function to check whether a particular file exists or not.
# * **Syntax** → `os.path.isfile(fname)`

# %% [markdown]
# ##  Program to check whether the given File exists OR not. If it is available then print its content.

# %% [markdown]
# ```
# import os, sys
#
# fname=input("Enter File Name: ")
# if os.path.isfile(fname):
#   print("File exists:",fname)
#   f=open(fname,"r")
# else:
#   print("File does not exist:",fname)
#   sys.exit(0)
# print("The content of file is:")
# data=f.read()
# print(data)
# ```
#
# ![image.png](attachment:a20cdcbb-7e4e-4c01-81b0-1f4c6ae2fc3e.png)
#
# **Note:**
# * **`sys.exit(0)`** → To exit system without executing rest of the program.
# * argument represents the status code.
# * `0` means normal termination and it is the default value.

# %% [markdown]
# ## Program to print the number of lines, words, and characters present in the given file?

# %% [markdown]
# ```
# import os,sys
#
# fname=input("Enter File Name: ")
# if os.path.isfile(fname):
#   print("File exists:",fname)
#   f=open(fname,"r")
# else:
#   print("File does not exist:",fname)
#   sys.exit(0)
#
# lcount=wcount=ccount=0
#
# for line in f:
#   lcount=lcount+1
#   ccount=ccount+len(line)
#   words=line.split()
#   wcount=wcount+len(words)
#
# print("The number of Lines:",lcount)
# print("The number of Words:",wcount)
# print("The number of Characters:",ccount)
# ```
#
# ![image.png](attachment:5d7484f2-296e-4b47-b456-2de7931a8f0b.png)
