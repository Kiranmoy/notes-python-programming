# %% [markdown]
# ![image.png](attachment:1e0028c4-fbec-4585-82d2-18279e50df29.png)

# %% [markdown]
# ***Note: Complex type is Immutable***

# %%
c = 10 + 20j
print(c)
print(id(c))
# Out:
# (10+20j)
# 1908395745040

# %%
c.real = 30
print(c)
print(id(c))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c.real = 30
#       2 print(c)
#       3 print(id(c))
#
# AttributeError: readonly attribute
