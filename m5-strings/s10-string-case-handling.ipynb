# %% [markdown]
# # Methods to change case of a string: upper( ), lower( ), swapcase( ), title( ) & capitalize( )

# %% [markdown]
# We can change the case of a string by using the following 4 methods:
#
# ![image.png](attachment:05802b25-67e7-4596-8aa6-ee2df7e38784.png)

# %%
s = 'learning Python is very Easy'

print(s.upper())        # LEARNING PYTHON IS VERY EASY

print(s.lower())        # learning python is very easy

print(s.swapcase())     # LEARNING pYTHON IS VERY eASY

print(s.title())        # Learning Python Is Very Easy

print(s.capitalize())   # Learning python is very easy
# Out:
# LEARNING PYTHON IS VERY EASY
# learning python is very easy
# LEARNING pYTHON IS VERY eASY
# Learning Python Is Very Easy
# Learning python is very easy
